# %% [markdown]
# # Import Libraries

# %%
#for data processing or visualization
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import cv2
import random
import math

#load data 
import os 

#for deep learning module
import torch 
from torch import nn 
from torchsummary import summary
from torch.utils.data import DataLoader, Dataset 
from torchvision import datasets
from torchvision import transforms

# %% [markdown]
# # Configurations

# %%
#define the loading list of data
ROOT = '/Users/r/Desktop/git_repository/machine_learning/dataset/UNET-Dataset/'

img_path = ROOT + 'CameraRGB/'
msk_path = ROOT + 'CameraMask/'

img_list = os.listdir(img_path) 
msk_list = os.listdir(msk_path)

img_list = [img_path + i for i in img_list]
msk_list = [msk_path + i for i in msk_list]

BATCH_SIZE = 32

LR = 1e-3

EPOCH = 100

DEVICE = 'mps'

# %% [markdown]
# # Have a look on the raw image and its mask

# %%
N = 0
img = plt.imread(img_list[N])
img = img[:,:,0:3]
msk = plt.imread(msk_list[N])

fig, ax = plt.subplots(1,2)
ax[0].imshow(img)
ax[0].set_title('original image')
ax[1].imshow(msk[:,:,0])
ax[1].set_title('segmentation mask')
# Out:
# Text(0.5, 1.0, 'segmentation mask')

# %%
train_augs = transforms.Compose([
    transforms.ToTensor()
])

def load_data(img_list, msk_list, new_h, new_w, augs):
    data_list = [None]*len(img_list)
    for i in range(len(img_list)):
        img = plt.imread(img_list[i])
        img = img[:,:,0:3]
        msk = plt.imread(msk_list[i])
        msk = msk[:, :, 0]*255
        img = cv2.resize(img, (new_w, new_h))
        msk = cv2.resize(msk, (new_w, new_h))
        
        img = augs(img)
        #msk = torch.tensor(msk, dtype = torch.float)
        msk = torch.tensor(msk)
        #msk = msk.view((1, msk.shape[0], msk.shape[1]))
        data_list[i] = (img, msk)
    
    return data_list

data_list = load_data(img_list, msk_list, 96, 128, train_augs)

# %%
fig, ax = plt.subplots(1, 2)

img, msk = data_list[0]

ax[0].imshow(img.permute(1,2,0))
ax[1].imshow(msk)

# %% [markdown]
# # Get mini-batch of Training Data

# %%
trainloader = DataLoader(data_list, batch_size = BATCH_SIZE, shuffle = True)

# %%
train_iter = iter(trainloader)
images, masks = next(train_iter)

print('images shape: ', images.shape)
print('masks shape: ', masks.shape)

fig, ax = plt.subplots(1, 2)
ax[0].imshow(images[0].permute(1,2,0))
ax[1].imshow(masks[0])
# Out:
# images shape:  torch.Size([32, 3, 96, 128])
# masks shape:  torch.Size([32, 96, 128])

# %% [markdown]
# # Construct Encoder Blocks

# %%
class DownConvBlock(nn.Module):
    def __init__(self, in_c, k_size = (3, 3), p_size = 1):
        super(DownConvBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c*2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv2 = nn.Conv2d(in_channels  = in_c*2, 
                          out_channels = in_c*2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.activation = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size = (2, 2), stride = 2)
        
    def forward(self, x):
        
        x = self.conv1(x)
        x = self.activation(x)
        x = self.conv2(x)
        x = self.activation(x)
        x = self.max_pool(x)
        
        return x

# %% [markdown]
# # Construct Decoder Blocks

# %%
class UpConvBlock(nn.Module):
    def __init__(self, in_c, k_size = (3, 3), p_size = 1):
        super(UpConvBlock, self).__init__()
        

        self.conv1 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv2 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv3 = nn.Conv2d(in_channels  = in_c//2, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.activation = nn.ReLU()
        self.upsample = nn.Upsample(scale_factor = 2, 
                                    mode = 'bilinear',
                                    align_corners=True)
        
    def forward(self, x, skip_x):
        
        x = self.upsample(x)
        x = self.conv1(x)
        x = torch.cat([x, skip_x], axis = 1)
        x = self.conv2(x)
        x = self.activation(x)
        x = self.conv3(x)
        x = self.activation(x)
        
        return x

# %% [markdown]
# # Construct Feature Maps

# %%
class FeatureMap(nn.Module):
    def __init__(self, in_c, out_c):
        super(FeatureMap, self).__init__()
        self.conv = nn.Conv2d(in_channels = in_c, 
                              out_channels = out_c, 
                              kernel_size = (1, 1))
    
    def forward(self, x):
        x = self.conv(x)
        return x

# %% [markdown]
# # Construct U-Net

# %%
class UNet(nn.Module):
    def __init__(self, in_c, out_c, h_c):
        super(UNet, self).__init__()
        self.upfeature = FeatureMap(in_c, h_c)
        self.contract1 = DownConvBlock(h_c)
        self.contract2 = DownConvBlock(h_c*2)
        self.contract3 = DownConvBlock(h_c*4)
        self.contract4 = DownConvBlock(h_c*8) 
        self.expand1 = UpConvBlock(h_c*16)
        self.expand2 = UpConvBlock(h_c*8)
        self.expand3 = UpConvBlock(h_c*4)
        self.expand4 = UpConvBlock(h_c*2)
        self.downfeature = FeatureMap(h_c, out_c)
        
    def forward(self, x):
        x0 = self.upfeature(x)
        x1 = self.contract1(x0)
        x2 = self.contract2(x1)
        x3 = self.contract3(x2)
        x4 = self.contract4(x3) #bridge between encoder and decoder
        x5 = self.expand1(x4, x3)
        x6 = self.expand2(x5, x2)
        x7 = self.expand3(x6, x1)
        x8 = self.expand4(x7, x0)
        out = self.downfeature(x8)
        
        return out

# %%
model = UNet(3, 23, 16)
summary(model, (3, 96, 128))
model.to(DEVICE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 16, 96, 128]              64
#         FeatureMap-2          [-1, 16, 96, 128]               0
#             Conv2d-3          [-1, 32, 96, 128]           4,640
#               ReLU-4          [-1, 32, 96, 128]               0
#             Conv2d-5          [-1, 32, 96, 128]           9,248
#               ReLU-6          [-1, 32, 96, 128]               0
#          MaxPool2d-7           [-1, 32, 48, 64]               0
#      DownConvBlock-8           [-1, 32, 48, 64]               0
#             Conv2d-9           [-1, 64, 48, 64]          18,496
#              ReLU-10           [-1, 64, 48, 64]               0
#            Conv2d-11           [-1, 64, 48, 64]          36,928
#              ReLU-12           [-1, 64, 48, 64]               0
#         MaxPool2d-13           [-1, 64, 24, 32]               0
#     DownConvBlock-14           [-1, 64, 24, 32]               0
#            Conv2d-15          [-1, 128, 24, 32]          73,856
#              ReLU-16          [-1, 128, 24, 32]               0
#            Conv2d-17          [-1, 128, 24, 32]         147,584
#              ReLU-18          [-1, 128, 24, 32]               0
#         MaxPool2d-19          [-1, 128, 12, 16]               0
#     DownConvBlock-20          [-1, 128, 12, 16]               0
#            Conv2d-21          [-1, 256, 12, 16]         295,168
#              ReLU-22          [-1, 256, 12, 16]               0
#            Conv2d-23          [-1, 256, 12, 16]         590,080
#              ReLU-24          [-1, 256, 12, 16]               0
#         MaxPool2d-25            [-1, 256, 6, 8]               0
#     DownConvBlock-26            [-1, 256, 6, 8]               0
#          Upsample-27          [-1, 256, 12, 16]               0
#            Conv2d-28          [-1, 128, 12, 16]         295,040
#            Conv2d-29          [-1, 128, 12, 16]         295,040
#              ReLU-30          [-1, 128, 12, 16]               0
#            Conv2d-31          [-1, 128, 12, 16]         147,584
#              ReLU-32          [-1, 128, 12, 16]               0
#       UpConvBlock-33          [-1, 128, 12, 16]               0
#          Upsample-34          [-1, 128, 24, 32]               0
#            Conv2d-35           [-1, 64, 24, 32]          73,792
#            Conv2d-36           [-1, 64, 24, 32]          73,792
#              ReLU-37           [-1, 64, 24, 32]               0
#            Conv2d-38           [-1, 64, 24, 32]          36,928
#              ReLU-39           [-1, 64, 24, 32]               0
#       UpConvBlock-40           [-1, 64, 24, 32]               0
#          Upsample-41           [-1, 64, 48, 64]               0
#            Conv2d-42           [-1, 32, 48, 64]          18,464
#            Conv2d-43           [-1, 32, 48, 64]          18,464
#              ReLU-44           [-1, 32, 48, 64]               0
#            Conv2d-45           [-1, 32, 48, 64]           9,248
#              ReLU-46           [-1, 32, 48, 64]               0
#       UpConvBlock-47           [-1, 32, 48, 64]               0
#          Upsample-48          [-1, 32, 96, 128]               0
#            Conv2d-49          [-1, 16, 96, 128]           4,624
#            Conv2d-50          [-1, 16, 96, 128]           4,624
#              ReLU-51          [-1, 16, 96, 128]               0
#            Conv2d-52          [-1, 16, 96, 128]           2,320
#              ReLU-53          [-1, 16, 96, 128]               0
#       UpConvBlock-54          [-1, 16, 96, 128]               0
#            Conv2d-55          [-1, 23, 96, 128]             391
#        FeatureMap-56          [-1, 23, 96, 128]               0
# ================================================================
# Total params: 2,156,375
# Trainable params: 2,156,375
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.14
# Forward/backward pass size (MB): 55.12
# Params size (MB): 8.23
# Estimated Total Size (MB): 63.49
# ----------------------------------------------------------------
# UNet(
#   (upfeature): FeatureMap(
#     (conv): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (contract1): DownConvBlock(
#     (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract2): DownConvBlock(
#     (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract3): DownConvBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract4): DownConvBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (expand1): UpConvBlock(
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand2): UpConvBlock(
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand3): UpConvBlock(
#     (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand4): UpConvBlock(
#     (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (downfeature): FeatureMap(
#     (conv): Conv2d(16, 23, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
#define training loop
def train_fcn(dataloader, model, criterion, opt):
    '''
    Args:
        dataloader: mini-batch of training data
        model     : convolutional neural network
        criterion : loss function for optimization
        opt       : optimizer for updating parameters of neural network
    Outputs:
        avg_loss  : average loss of one training epoch
    '''
    
    
    model.train()
    total_loss = 0.0
    total_acc = 0.0
    n = 0
    #accuracy = torch.Accuracy(task="multiclass", num_classes=23)
    for (images, labels) in dataloader:
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        opt.zero_grad()
        preds = model(images)
        loss = criterion(preds, labels.long())
        preds_max = torch.argmax(preds, dim = 1, keepdim = True)
        preds_max = preds_max[:,0,:,:]
        #print('preds_max: ', preds_max.shape)
        #print('labels: ', labels.shape)
        
        loss.backward()
        opt.step()
        
        total_loss += loss.item()
        total_acc += torch.sum(preds_max == labels)/(96*128*BATCH_SIZE)
        
        n += 1
    avg_loss = total_loss/n
    avg_acc = total_acc/n
    #avg_acc = None
    return avg_loss, avg_acc

# %%
#define the optimizer
opt = torch.optim.Adam(model.parameters(), lr = LR)
#define the loss
criterion = torch.nn.CrossEntropyLoss()

#start training 
best_valid_loss = np.Inf
train_loss_list = [None]*EPOCH
valid_loss_list = [None]*EPOCH


for i in range(EPOCH):
    train_loss_list[i], acc = train_fcn(trainloader, model, criterion, opt)
    #valid_loss_list[i] = eval_fcn(validloader, model, criterion)
    
    #save better model with lower validation loss
    #if valid_loss_list[i] < best_valid_loss:
    #    best_valid_loss =  valid_loss_list[i]
    #    torch.save(model.state_dict(), 'best_weights.pt')
    #    print('Found and saved model!')
        
    #print(f'epoch {i + 1} training loss: {train_loss_list[i] :.2f}, validation loss : {valid_loss_list[i] :.2f}')
    print(f'epoch {i + 1} training loss: {train_loss_list[i] :.2f} accuracy: {acc*100 :.2f}%')
# Out:
# epoch 1 training loss: 2.49 accuracy: 31.11%
# epoch 2 training loss: 1.61 accuracy: 41.09%
# epoch 3 training loss: 1.25 accuracy: 62.15%
# epoch 4 training loss: 0.76 accuracy: 77.38%
# epoch 5 training loss: 0.67 accuracy: 78.50%
# epoch 6 training loss: 0.62 accuracy: 79.24%
# epoch 7 training loss: 0.59 accuracy: 79.95%
# epoch 8 training loss: 0.55 accuracy: 80.95%
# epoch 9 training loss: 0.55 accuracy: 81.17%
# epoch 10 training loss: 0.54 accuracy: 81.49%
# epoch 11 training loss: 0.52 accuracy: 82.08%
# epoch 12 training loss: 0.53 accuracy: 82.12%
# epoch 13 training loss: 0.50 accuracy: 82.77%
# epoch 14 training loss: 0.50 accuracy: 83.05%
# epoch 15 training loss: 0.45 accuracy: 84.36%
# epoch 16 training loss: 0.40 accuracy: 85.55%
# epoch 17 training loss: 0.38 accuracy: 86.06%
# epoch 18 training loss: 0.36 accuracy: 86.60%
# epoch 19 training loss: 0.33 accuracy: 87.17%
# epoch 20 training loss: 0.31 accuracy: 87.84%
# epoch 21 training loss: 0.30 accuracy: 88.31%
# epoch 22 training loss: 0.28 accuracy: 88.90%
# epoch 23 training loss: 0.28 accuracy: 89.27%
# epoch 24 training loss: 0.37 accuracy: 86.74%
# epoch 25 training loss: 0.27 accuracy: 89.33%
# epoch 26 training loss: 0.25 accuracy: 90.05%
# epoch 27 training loss: 0.24 accuracy: 90.20%
# epoch 28 training loss: 0.22 accuracy: 90.79%
# epoch 29 training loss: 0.22 accuracy: 91.03%
# epoch 30 training loss: 0.21 accuracy: 91.15%
# epoch 31 training loss: 0.20 accuracy: 91.51%
# epoch 32 training loss: 0.19 accuracy: 91.65%
# epoch 33 training loss: 0.19 accuracy: 91.67%
# epoch 34 training loss: 0.18 accuracy: 91.92%
# epoch 35 training loss: 0.18 accuracy: 91.95%
# epoch 36 training loss: 0.18 accuracy: 92.18%
# epoch 37 training loss: 0.19 accuracy: 91.81%
# epoch 38 training loss: 0.17 accuracy: 92.30%
# epoch 39 training loss: 0.16 accuracy: 92.60%
# epoch 40 training loss: 0.17 accuracy: 92.49%
# epoch 41 training loss: 0.17 accuracy: 92.43%
# epoch 42 training loss: 0.18 accuracy: 92.02%
# epoch 43 training loss: 0.16 accuracy: 92.70%
# epoch 44 training loss: 0.15 accuracy: 92.93%
# epoch 45 training loss: 0.15 accuracy: 93.09%
# epoch 46 training loss: 0.15 accuracy: 92.99%
# epoch 47 training loss: 0.14 accuracy: 93.23%
# epoch 48 training loss: 0.14 accuracy: 93.37%
# epoch 49 training loss: 0.14 accuracy: 93.33%
# epoch 50 training loss: 0.14 accuracy: 93.36%
# epoch 51 training loss: 0.13 accuracy: 93.51%
# epoch 52 training loss: 0.13 accuracy: 93.36%
# epoch 53 training loss: 0.13 accuracy: 93.59%
# epoch 54 training loss: 0.12 accuracy: 93.71%
# epoch 55 training loss: 0.12 accuracy: 93.81%
# epoch 56 training loss: 0.12 accuracy: 93.82%
# epoch 57 training loss: 0.12 accuracy: 93.66%
# epoch 58 training loss: 0.12 accuracy: 93.82%
# epoch 59 training loss: 0.12 accuracy: 93.88%
# epoch 60 training loss: 0.11 accuracy: 93.98%
# epoch 61 training loss: 0.11 accuracy: 94.06%
# epoch 62 training loss: 0.12 accuracy: 93.91%
# epoch 63 training loss: 0.11 accuracy: 94.07%
# epoch 64 training loss: 0.11 accuracy: 94.12%
# epoch 65 training loss: 0.11 accuracy: 94.03%
# epoch 66 training loss: 0.11 accuracy: 94.11%
# epoch 67 training loss: 0.11 accuracy: 94.20%
# epoch 68 training loss: 0.11 accuracy: 94.24%
# epoch 69 training loss: 0.11 accuracy: 94.21%
# epoch 70 training loss: 0.11 accuracy: 94.11%
# epoch 71 training loss: 0.11 accuracy: 94.03%
# epoch 72 training loss: 0.11 accuracy: 94.25%
# epoch 73 training loss: 0.10 accuracy: 94.34%
# epoch 74 training loss: 0.10 accuracy: 94.37%
# epoch 75 training loss: 0.10 accuracy: 94.49%
# epoch 76 training loss: 0.10 accuracy: 94.52%
# epoch 77 training loss: 0.11 accuracy: 94.21%
# epoch 78 training loss: 0.10 accuracy: 94.42%
# epoch 79 training loss: 0.10 accuracy: 94.32%
# epoch 80 training loss: 0.10 accuracy: 94.51%
# epoch 81 training loss: 0.09 accuracy: 94.58%
# epoch 82 training loss: 0.09 accuracy: 94.63%
# epoch 83 training loss: 0.09 accuracy: 94.58%
# epoch 84 training loss: 0.09 accuracy: 94.64%
# epoch 85 training loss: 0.09 accuracy: 94.66%
# epoch 86 training loss: 0.09 accuracy: 94.53%
# epoch 87 training loss: 0.09 accuracy: 94.67%
# epoch 88 training loss: 0.10 accuracy: 94.52%
# epoch 89 training loss: 0.09 accuracy: 94.56%
# epoch 90 training loss: 0.09 accuracy: 94.73%
# epoch 91 training loss: 0.09 accuracy: 94.75%
# epoch 92 training loss: 0.09 accuracy: 94.74%
# epoch 93 training loss: 0.09 accuracy: 94.70%
# epoch 94 training loss: 0.09 accuracy: 94.65%
# epoch 95 training loss: 0.09 accuracy: 94.68%
# epoch 96 training loss: 0.09 accuracy: 94.67%
# epoch 97 training loss: 0.09 accuracy: 94.73%
# epoch 98 training loss: 0.11 accuracy: 94.08%
# epoch 99 training loss: 0.09 accuracy: 94.72%
# epoch 100 training loss: 0.08 accuracy: 94.83%

# %%
train_iter = iter(trainloader)
images, masks = next(train_iter)

model.eval()
preds = model(images.to(DEVICE))
preds = torch.argmax(preds, dim = 1, keepdim = True)

for i, image in enumerate(images):
    fig, ax = plt.subplots(1, 3, figsize = (20, 20))
    ax[0].imshow(image.permute(1,2,0))
    ax[0].set_title('Original Image')
    ax[1].imshow(masks[i])
    ax[1].set_title('Ground Truth')
    ax[2].imshow(preds[i].permute(1,2,0).detach().cpu().numpy())
    ax[2].set_title('Prediction')
# Out:
# /var/folders/vg/qjx94k1s147g4n3ybsntyyd80000gn/T/ipykernel_7071/1990653545.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(1, 3, figsize = (20, 20))
