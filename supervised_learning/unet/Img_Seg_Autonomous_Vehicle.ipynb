# %% [markdown]
# # Import Libraries

# %%
#for data processing or visualization
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import cv2
import random
import math

#load data 
import os 

#for deep learning module
import torch 
from torch import nn 
from torchsummary import summary
from torch.utils.data import DataLoader, Dataset 
from torchvision import datasets
from torchvision import transforms
from segmentation_models_pytorch.losses import DiceLoss

# %% [markdown]
# # Configurations

# %%
#define the loading list of data
ROOT = '/Users/r/Desktop/git_repository/machine_learning/dataset/UNET-Dataset/'
img_path = ROOT + 'CameraRGB/'
msk_path = ROOT + 'CameraMask/'

#get the directories of image and mask
img_dirs = os.listdir(img_path) 
msk_dirs = os.listdir(msk_path)

#to ensure the mask is corresponding to the correct image
img_dirs = np.sort(img_dirs)
msk_dirs = np.sort(msk_dirs)

#obtain absolute paths for loading data in the future
img_list = [img_path + i for i in img_dirs]
msk_list = [msk_path + i for i in msk_dirs]

#define the batch size of training/validation/test data
BATCH_SIZE = 8

#define if loading the previous trained model
LOADING = False

#define the learning rate
LR = 1e-3

#define the number of training epoch
EPOCH = 75

#define the input size of image
IMG_H = 128
IMG_W = 128

#define which device is used for training/evaluation
DEVICE = 'mps'

# %% [markdown]
# # Have a look on the raw image and its mask

# %%
idx = 1
img = plt.imread(img_list[idx])
img = img[:,:,0:3]
msk = plt.imread(msk_list[idx])
msk = msk[:,:,0]

fig, ax = plt.subplots(1,2)
ax[0].imshow(img)
ax[1].imshow(msk)

ax[0].set_title('image')
ax[1].set_title('mask')
# Out:
# Text(0.5, 1.0, 'mask')

# %%
#define training augmentation 
train_augs = transforms.Compose([
    transforms.ToTensor()
])


def load_data(img_list, msk_list, new_h, new_w, augs):
    
    """
    Args:
        img_list : list of image paths
        msk_list : list of mask paths
        new_h    : resized image height
        new_w    : resized image width
        augs     : data augmentation
    Outputs:
        data_list: list of data including image and corresponding mask
    """
    
    data_list = [None]*len(img_list)
    for i in range(len(img_list)):
        img = plt.imread(img_list[i])
        img = img[:,:,0:3]
        msk = plt.imread(msk_list[i])
        msk = msk[:,:,0]
        img = cv2.resize(img, (new_w, new_h))
        msk = cv2.resize(msk, (new_w, new_h))
        
        img = augs(img)
        msk = augs(msk)*255
        data_list[i] = [img, msk[0,:,:]]
    
    return data_list

data_list = load_data(img_list, msk_list, IMG_H, IMG_W, train_augs)

# %%
fig, ax = plt.subplots(1, 2)
img, msk = data_list[4]
print(img.shape, msk.shape)

ax[0].imshow(img.permute(1, 2, 0))
ax[1].imshow(img.permute(1, 2, 0))
ax[1].imshow(msk, cmap = 'jet', alpha = 0.7)
# Out:
# torch.Size([3, 128, 128]) torch.Size([128, 128])

# %% [markdown]
# # Split into Training, Validation and Testing Data

# %%
def split_ids(data, train=.7, valid=0.1, test=0.2, seed = 0):
    """
    Args:
        image_id_list (int list): list of unique image ids
        train (float): train split size (between 0 - 1)
        valid (float): valid split size (between 0 - 1)
        test  (float): test split size (between 0 - 1)
    Outputs:
        train_set: list of training data
        valid_set: list of validation data
        test_set: list of testing data
    """
    
    list_copy = list(range(0, len(data)))
    random.Random(seed).shuffle(list_copy)
    
    #obtain the size of training, validation and testing data
    train_size = math.floor(len(list_copy) * train)
    valid_size = math.floor(len(list_copy) * valid)
    test_size = len(list_copy) - train_size - valid_size
    
    train_set = [None]*train_size
    if train + valid == 1.0:
        valid_size += test_size
        valid_set = [None]*valid_size
        test_set  = None
        test_size = 0
    else:
        valid_set = [None]*valid_size
        test_set  = [None]*test_size
    
    #split the data into training, validation and testing dataset
    idx = 0
    for cnt, i in enumerate(list_copy):
        
        if cnt == train_size or cnt == train_size + valid_size:
            idx = 0
            
        if cnt < train_size:
            train_set[idx]= [data[i][0], 
                             data[i][1]]
        elif cnt >= train_size and cnt < train_size + valid_size:
            valid_set[idx]= [data[i][0], 
                             data[i][1]]
        else:
            test_set[idx] = [data[i][0], 
                             data[i][1]]
        idx += 1
        
    return train_set, valid_set, test_set

# %%
train_data, valid_data, test_data = split_ids(data_list, train = 0.7, valid = 0.15, test = 0.15)

#check if the training and validation dataset are in correct proportion
N_data  = len(data_list)
N_train = len(train_data)
N_valid = len(valid_data)
N_test  = len(test_data)

print(f'Total number of data: {N_data}')
print(f'Total number of training data: {N_train} ({N_train/N_data :.2f})')
print(f'Total number of validation data: {N_valid} ({N_valid/N_data :.2f})')
print(f'Total number of testing data: {N_test} ({N_test/N_data :.2f})')
# Out:
# Total number of data: 1060
# Total number of training data: 742 (0.70)
# Total number of validation data: 159 (0.15)
# Total number of testing data: 159 (0.15)

# %% [markdown]
# # Get mini-batch of Training Data

# %%
trainloader = DataLoader(train_data, batch_size = BATCH_SIZE, shuffle = True)
validloader = DataLoader(valid_data, batch_size = BATCH_SIZE, shuffle = False)
testloader = DataLoader(test_data, batch_size = BATCH_SIZE, shuffle = False)

data_iter = iter(trainloader)

# %%
images, masks = next(data_iter)

print('images shape: ', images.shape)
print('masks shape: ', masks.shape)

fig, ax = plt.subplots(1, 2)
ax[0].imshow(images[0].permute(1,2,0))

ax[1].imshow(images[0].permute(1,2,0))
ax[1].imshow(masks[0,:,:], cmap = 'jet', alpha = 0.7)
# Out:
# images shape:  torch.Size([8, 3, 128, 128])
# masks shape:  torch.Size([8, 128, 128])

# %% [markdown]
# # Construct Encoder Blocks

# %%
class DownConvBlock(nn.Module):
    def __init__(self, in_c, k_size = (3, 3), p_size = 1):

        '''
        Args:
            in_c: input channel size
            k_size : kernel size
            p_size : padding size
        '''
        
        super(DownConvBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c*2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv2 = nn.Conv2d(in_channels  = in_c*2, 
                          out_channels = in_c*2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.activation = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size = (2, 2), stride = 2)
        
    def forward(self, x):
        
        '''
        Args:
            x: input from upper level
            skip_x : skip input from encoder
        '''
        
        x = self.conv1(x)
        x = self.activation(x)
        x = self.conv2(x)
        x = self.activation(x)
        x = self.max_pool(x)
        
        return x

# %% [markdown]
# # Construct Decoder Blocks

# %%
class UpConvBlock(nn.Module):
    def __init__(self, in_c, k_size = (3, 3), p_size = 1):
        
        '''
        Args:
            in_c: input channel size
            k_size : kernel size
            p_size : padding size
        '''
        
        super(UpConvBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv2 = nn.Conv2d(in_channels  = in_c, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.conv3 = nn.Conv2d(in_channels  = in_c//2, 
                          out_channels = in_c//2,
                          kernel_size  = k_size,
                          padding = p_size)
        self.activation = nn.ReLU()
        self.upsample = nn.Upsample(scale_factor = 2, 
                                    mode = 'bilinear',
                                    align_corners=True)
        
    def forward(self, x, skip_x):
        
        '''
        Args:
            x: input from lower level
            skip_x : skip input from encoder
        '''
        
        x = self.upsample(x)
        x = self.conv1(x)
        x = torch.cat([x, skip_x], axis = 1)
        x = self.conv2(x)
        x = self.activation(x)
        x = self.conv3(x)
        x = self.activation(x)
        
        return x

# %% [markdown]
# # Construct Feature Maps

# %%
class FeatureMap(nn.Module):
    def __init__(self, in_c, out_c):
        super(FeatureMap, self).__init__()
        self.conv = nn.Conv2d(in_channels = in_c, 
                              out_channels = out_c, 
                              kernel_size = (1, 1))
    
    def forward(self, x):
        x = self.conv(x)
        return x

# %% [markdown]
# # Construct U-Net

# %%
class UNet(nn.Module):
    def __init__(self, in_c, out_c, h_c):
        super(UNet, self).__init__()
        self.upfeature = FeatureMap(in_c, h_c)
        self.contract1 = DownConvBlock(h_c)
        self.contract2 = DownConvBlock(h_c*2)
        self.contract3 = DownConvBlock(h_c*4)
        self.contract4 = DownConvBlock(h_c*8) 
        self.expand1 = UpConvBlock(h_c*16)
        self.expand2 = UpConvBlock(h_c*8)
        self.expand3 = UpConvBlock(h_c*4)
        self.expand4 = UpConvBlock(h_c*2)
        self.downfeature = FeatureMap(h_c, out_c)
        
    def forward(self, x):
        x0 = self.upfeature(x)
        x1 = self.contract1(x0)
        x2 = self.contract2(x1)
        x3 = self.contract3(x2)
        x4 = self.contract4(x3) 
        x5 = self.expand1(x4, x3)
        x6 = self.expand2(x5, x2)
        x7 = self.expand3(x6, x1)
        x8 = self.expand4(x7, x0)
        out = self.downfeature(x8)
        
        return out

# %%
model = UNet(3, 23, 16)
summary(model, (3, IMG_H, IMG_W))
model.to(DEVICE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 128]              64
#         FeatureMap-2         [-1, 16, 128, 128]               0
#             Conv2d-3         [-1, 32, 128, 128]           4,640
#               ReLU-4         [-1, 32, 128, 128]               0
#             Conv2d-5         [-1, 32, 128, 128]           9,248
#               ReLU-6         [-1, 32, 128, 128]               0
#          MaxPool2d-7           [-1, 32, 64, 64]               0
#      DownConvBlock-8           [-1, 32, 64, 64]               0
#             Conv2d-9           [-1, 64, 64, 64]          18,496
#              ReLU-10           [-1, 64, 64, 64]               0
#            Conv2d-11           [-1, 64, 64, 64]          36,928
#              ReLU-12           [-1, 64, 64, 64]               0
#         MaxPool2d-13           [-1, 64, 32, 32]               0
#     DownConvBlock-14           [-1, 64, 32, 32]               0
#            Conv2d-15          [-1, 128, 32, 32]          73,856
#              ReLU-16          [-1, 128, 32, 32]               0
#            Conv2d-17          [-1, 128, 32, 32]         147,584
#              ReLU-18          [-1, 128, 32, 32]               0
#         MaxPool2d-19          [-1, 128, 16, 16]               0
#     DownConvBlock-20          [-1, 128, 16, 16]               0
#            Conv2d-21          [-1, 256, 16, 16]         295,168
#              ReLU-22          [-1, 256, 16, 16]               0
#            Conv2d-23          [-1, 256, 16, 16]         590,080
#              ReLU-24          [-1, 256, 16, 16]               0
#         MaxPool2d-25            [-1, 256, 8, 8]               0
#     DownConvBlock-26            [-1, 256, 8, 8]               0
#          Upsample-27          [-1, 256, 16, 16]               0
#            Conv2d-28          [-1, 128, 16, 16]         295,040
#            Conv2d-29          [-1, 128, 16, 16]         295,040
#              ReLU-30          [-1, 128, 16, 16]               0
#            Conv2d-31          [-1, 128, 16, 16]         147,584
#              ReLU-32          [-1, 128, 16, 16]               0
#       UpConvBlock-33          [-1, 128, 16, 16]               0
#          Upsample-34          [-1, 128, 32, 32]               0
#            Conv2d-35           [-1, 64, 32, 32]          73,792
#            Conv2d-36           [-1, 64, 32, 32]          73,792
#              ReLU-37           [-1, 64, 32, 32]               0
#            Conv2d-38           [-1, 64, 32, 32]          36,928
#              ReLU-39           [-1, 64, 32, 32]               0
#       UpConvBlock-40           [-1, 64, 32, 32]               0
#          Upsample-41           [-1, 64, 64, 64]               0
#            Conv2d-42           [-1, 32, 64, 64]          18,464
#            Conv2d-43           [-1, 32, 64, 64]          18,464
#              ReLU-44           [-1, 32, 64, 64]               0
#            Conv2d-45           [-1, 32, 64, 64]           9,248
#              ReLU-46           [-1, 32, 64, 64]               0
#       UpConvBlock-47           [-1, 32, 64, 64]               0
#          Upsample-48         [-1, 32, 128, 128]               0
#            Conv2d-49         [-1, 16, 128, 128]           4,624
#            Conv2d-50         [-1, 16, 128, 128]           4,624
#              ReLU-51         [-1, 16, 128, 128]               0
#            Conv2d-52         [-1, 16, 128, 128]           2,320
#              ReLU-53         [-1, 16, 128, 128]               0
#       UpConvBlock-54         [-1, 16, 128, 128]               0
#            Conv2d-55         [-1, 23, 128, 128]             391
#        FeatureMap-56         [-1, 23, 128, 128]               0
# ================================================================
# Total params: 2,156,375
# Trainable params: 2,156,375
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 73.50
# Params size (MB): 8.23
# Estimated Total Size (MB): 81.91
# ----------------------------------------------------------------
# UNet(
#   (upfeature): FeatureMap(
#     (conv): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (contract1): DownConvBlock(
#     (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract2): DownConvBlock(
#     (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract3): DownConvBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract4): DownConvBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (expand1): UpConvBlock(
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand2): UpConvBlock(
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand3): UpConvBlock(
#     (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand4): UpConvBlock(
#     (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (downfeature): FeatureMap(
#     (conv): Conv2d(16, 23, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
#define training loop
def train_fcn(dataloader, model, criterion, opt):
    '''
    Args:
        dataloader: mini-batch of training data
        model     : convolutional neural network
        criterion : loss function for optimization
        opt       : optimizer for updating parameters of neural network
    Outputs:
        avg_loss  : average loss of one training epoch
    '''
    
    
    model.train()
    total_loss = 0.0
    total_acc = 0.0
    n = 0

    for (images, labels) in dataloader:
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        opt.zero_grad()
        preds = model(images)
        loss = criterion(preds, labels.long())
        preds_max = torch.argmax(preds, dim = 1)
        loss.backward()
        opt.step()

        total_loss += loss.item()
        total_acc += torch.sum(preds_max == labels)/(IMG_H*IMG_W*BATCH_SIZE)

        n += 1
            
    avg_loss = total_loss/n
    avg_acc = total_acc/n

    return avg_loss, avg_acc

# %%
#define training loop
def eval_fcn(dataloader, model, criterion):
    '''
    Args:
        dataloader: mini-batch of training data
        model     : convolutional neural network
        criterion : loss function for optimization
    Outputs:
        avg_loss  : average loss of one evaluation epoch
    '''
    
    
    model.eval()
    total_loss = 0.0
    total_acc = 0.0
    n = 0
    for (images, labels) in dataloader:
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        preds = model(images)
        loss = criterion(preds, labels.long())
        preds_max = torch.argmax(preds, dim = 1)
        total_loss += loss.item()
        total_acc += torch.sum(preds_max == labels)/(IMG_H*IMG_W*BATCH_SIZE)

        n += 1
        
    avg_loss = total_loss/n
    avg_acc = total_acc/n

    return avg_loss, avg_acc

# %%
#define the optimizer
opt = torch.optim.Adam(model.parameters(), lr = LR)
#define the loss
criterion = torch.nn.CrossEntropyLoss()
#initialize best_valid_loss
best_valid_loss = np.Inf

# %%
if LOADING:
    #if model has been trained before, load the model parameters
    data = torch.load('best_weights.pt')
    model.load_state_dict(data)
    print("load model successful!")
else:
    #initialize training and validation loss history 
    train_loss_list = [None]*EPOCH
    valid_loss_list = [None]*EPOCH
    train_acc_list = [None]*EPOCH
    valid_acc_list = [None]*EPOCH
    #start training 
    for i in range(EPOCH):
        train_loss_list[i], train_acc_list[i] = train_fcn(trainloader, model, criterion, opt)
        valid_loss_list[i], valid_acc_list[i]  =  eval_fcn(validloader, model, criterion)

        #save better model with lower validation loss
        print(f'Epoch {i + 1}: ')
        if valid_loss_list[i] < best_valid_loss:
            best_valid_loss =  valid_loss_list[i]
            torch.save(model.state_dict(), 'best_weights.pt')
            print(f'[Found and saved model!]')

        print(f'Training loss: {train_loss_list[i] :.2f}, Validation loss: {valid_loss_list[i] :.2f}')
        print(f'Training acc: {train_acc_list[i]*100 :.2f}%, Validation acc: {valid_acc_list[i]*100 :.2f}%')
        torch.save({"state_dict": model.state_dict(), 
                    "train_losses": train_loss_list, 
                    "valid_losses": valid_loss_list,
                    "train_acc": train_acc_list, 
                    "valid_acc": valid_acc_list,             
                   }, 'check_pt,pt')
# Out:
# Epoch 1:
# [Found and saved model!]
# Training loss: 1.93, Validation loss: 1.52
# Training acc: 36.35%, Validation acc: 44.30%
# Epoch 2:
# [Found and saved model!]
# Training loss: 1.18, Validation loss: 0.83
# Training acc: 63.66%, Validation acc: 78.77%
# Epoch 3:
# [Found and saved model!]
# Training loss: 0.69, Validation loss: 0.62
# Training acc: 79.29%, Validation acc: 80.46%
# Epoch 4:
# [Found and saved model!]
# Training loss: 0.61, Validation loss: 0.59
# Training acc: 81.15%, Validation acc: 81.99%
# Epoch 5:
# [Found and saved model!]
# Training loss: 0.58, Validation loss: 0.56
# Training acc: 82.36%, Validation acc: 82.53%
# Epoch 6:
# [Found and saved model!]
# Training loss: 0.57, Validation loss: 0.54
# Training acc: 82.56%, Validation acc: 82.92%
# Epoch 7:
# Training loss: 0.56, Validation loss: 0.54
# Training acc: 82.96%, Validation acc: 82.92%
# Epoch 8:
# [Found and saved model!]
# Training loss: 0.50, Validation loss: 0.48
# Training acc: 84.60%, Validation acc: 85.24%
# Epoch 9:
# [Found and saved model!]
# Training loss: 0.48, Validation loss: 0.47
# Training acc: 85.70%, Validation acc: 85.26%
# Epoch 10:
# [Found and saved model!]
# Training loss: 0.48, Validation loss: 0.45
# Training acc: 85.83%, Validation acc: 86.11%
# Epoch 11:
# [Found and saved model!]
# Training loss: 0.44, Validation loss: 0.45
# Training acc: 86.88%, Validation acc: 85.90%
# Epoch 12:
# Training loss: 0.43, Validation loss: 0.48
# Training acc: 87.33%, Validation acc: 86.10%
# Epoch 13:
# Training loss: 0.42, Validation loss: 0.47
# Training acc: 87.99%, Validation acc: 85.52%
# Epoch 14:
# [Found and saved model!]
# Training loss: 0.40, Validation loss: 0.41
# Training acc: 88.60%, Validation acc: 88.00%
# Epoch 15:
# [Found and saved model!]
# Training loss: 0.36, Validation loss: 0.39
# Training acc: 89.58%, Validation acc: 88.34%
# Epoch 16:
# [Found and saved model!]
# Training loss: 0.35, Validation loss: 0.36
# Training acc: 89.92%, Validation acc: 89.46%
# Epoch 17:
# [Found and saved model!]
# Training loss: 0.33, Validation loss: 0.31
# Training acc: 90.79%, Validation acc: 90.85%
# Epoch 18:
# [Found and saved model!]
# Training loss: 0.31, Validation loss: 0.31
# Training acc: 91.21%, Validation acc: 91.07%
# Epoch 19:
# [Found and saved model!]
# Training loss: 0.28, Validation loss: 0.28
# Training acc: 91.98%, Validation acc: 91.82%
# Epoch 20:
# Training loss: 0.27, Validation loss: 0.31
# Training acc: 92.45%, Validation acc: 90.83%
# Epoch 21:
# [Found and saved model!]
# Training loss: 0.28, Validation loss: 0.27
# Training acc: 92.02%, Validation acc: 91.88%
# Epoch 22:
# [Found and saved model!]
# Training loss: 0.25, Validation loss: 0.26
# Training acc: 92.94%, Validation acc: 92.42%
# Epoch 23:
# [Found and saved model!]
# Training loss: 0.24, Validation loss: 0.24
# Training acc: 93.27%, Validation acc: 92.76%
# Epoch 24:
# [Found and saved model!]
# Training loss: 0.23, Validation loss: 0.24
# Training acc: 93.50%, Validation acc: 92.97%
# Epoch 25:
# [Found and saved model!]
# Training loss: 0.22, Validation loss: 0.23
# Training acc: 93.63%, Validation acc: 93.11%
# Epoch 26:
# [Found and saved model!]
# Training loss: 0.22, Validation loss: 0.22
# Training acc: 93.80%, Validation acc: 93.46%
# Epoch 27:
# Training loss: 0.21, Validation loss: 0.22
# Training acc: 93.98%, Validation acc: 93.34%
# Epoch 28:
# [Found and saved model!]
# Training loss: 0.21, Validation loss: 0.22
# Training acc: 93.93%, Validation acc: 93.40%
# Epoch 29:
# [Found and saved model!]
# Training loss: 0.20, Validation loss: 0.21
# Training acc: 94.13%, Validation acc: 93.62%
# Epoch 30:
# [Found and saved model!]
# Training loss: 0.20, Validation loss: 0.21
# Training acc: 94.25%, Validation acc: 93.65%
# Epoch 31:
# [Found and saved model!]
# Training loss: 0.19, Validation loss: 0.20
# Training acc: 94.42%, Validation acc: 93.97%
# Epoch 32:
# Training loss: 0.21, Validation loss: 0.22
# Training acc: 93.80%, Validation acc: 93.17%
# Epoch 33:
# Training loss: 0.19, Validation loss: 0.21
# Training acc: 94.44%, Validation acc: 93.61%
# Epoch 34:
# [Found and saved model!]
# Training loss: 0.19, Validation loss: 0.19
# Training acc: 94.54%, Validation acc: 94.10%
# Epoch 35:
# Training loss: 0.18, Validation loss: 0.20
# Training acc: 94.82%, Validation acc: 93.92%
# Epoch 36:
# [Found and saved model!]
# Training loss: 0.18, Validation loss: 0.19
# Training acc: 94.68%, Validation acc: 94.13%
# Epoch 37:
# [Found and saved model!]
# Training loss: 0.17, Validation loss: 0.18
# Training acc: 94.83%, Validation acc: 94.34%
# Epoch 38:
# Training loss: 0.19, Validation loss: 0.19
# Training acc: 94.28%, Validation acc: 94.23%
# Epoch 39:
# Training loss: 0.18, Validation loss: 0.20
# Training acc: 94.72%, Validation acc: 93.89%
# Epoch 40:
# Training loss: 0.17, Validation loss: 0.19
# Training acc: 94.85%, Validation acc: 94.19%
# Epoch 41:
# [Found and saved model!]
# Training loss: 0.17, Validation loss: 0.18
# Training acc: 95.03%, Validation acc: 94.33%
# Epoch 42:
# [Found and saved model!]
# Training loss: 0.16, Validation loss: 0.18
# Training acc: 95.08%, Validation acc: 94.40%
# Epoch 43:
# Training loss: 0.17, Validation loss: 0.18
# Training acc: 95.00%, Validation acc: 94.21%
# Epoch 44:
# Training loss: 0.18, Validation loss: 0.18
# Training acc: 94.59%, Validation acc: 94.22%
# Epoch 45:
# [Found and saved model!]
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.06%, Validation acc: 94.66%
# Epoch 46:
# Training loss: 0.16, Validation loss: 0.18
# Training acc: 95.24%, Validation acc: 94.46%
# Epoch 47:
# [Found and saved model!]
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.26%, Validation acc: 94.71%
# Epoch 48:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.23%, Validation acc: 94.62%
# Epoch 49:
# [Found and saved model!]
# Training loss: 0.15, Validation loss: 0.17
# Training acc: 95.34%, Validation acc: 94.67%
# Epoch 50:
# [Found and saved model!]
# Training loss: 0.15, Validation loss: 0.17
# Training acc: 95.39%, Validation acc: 94.71%
# Epoch 51:
# Training loss: 0.15, Validation loss: 0.18
# Training acc: 95.44%, Validation acc: 94.22%
# Epoch 52:
# Training loss: 0.21, Validation loss: 0.22
# Training acc: 94.00%, Validation acc: 93.17%
# Epoch 53:
# Training loss: 0.20, Validation loss: 0.18
# Training acc: 94.08%, Validation acc: 94.34%
# Epoch 54:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.23%, Validation acc: 94.61%
# Epoch 55:
# [Found and saved model!]
# Training loss: 0.15, Validation loss: 0.16
# Training acc: 95.34%, Validation acc: 94.85%
# Epoch 56:
# [Found and saved model!]
# Training loss: 0.15, Validation loss: 0.16
# Training acc: 95.46%, Validation acc: 95.00%
# Epoch 57:
# Training loss: 0.14, Validation loss: 0.16
# Training acc: 95.54%, Validation acc: 94.92%
# Epoch 58:
# Training loss: 0.25, Validation loss: 1.21
# Training acc: 92.80%, Validation acc: 71.76%
# Epoch 59:
# Training loss: 0.53, Validation loss: 0.39
# Training acc: 85.59%, Validation acc: 87.91%
# Epoch 60:
# Training loss: 0.35, Validation loss: 0.33
# Training acc: 89.74%, Validation acc: 90.01%
# Epoch 61:
# Training loss: 0.29, Validation loss: 0.29
# Training acc: 91.39%, Validation acc: 91.02%
# Epoch 62:
# Training loss: 0.25, Validation loss: 0.25
# Training acc: 92.66%, Validation acc: 92.31%
# Epoch 63:
# Training loss: 0.23, Validation loss: 0.24
# Training acc: 93.33%, Validation acc: 92.81%
# Epoch 64:
# Training loss: 0.23, Validation loss: 0.22
# Training acc: 93.41%, Validation acc: 93.18%
# Epoch 65:
# Training loss: 0.20, Validation loss: 0.21
# Training acc: 94.20%, Validation acc: 93.70%
# Epoch 66:
# Training loss: 0.19, Validation loss: 0.20
# Training acc: 94.46%, Validation acc: 93.90%
# Epoch 67:
# Training loss: 0.19, Validation loss: 0.19
# Training acc: 94.61%, Validation acc: 94.08%
# Epoch 68:
# Training loss: 0.18, Validation loss: 0.19
# Training acc: 94.80%, Validation acc: 94.16%
# Epoch 69:
# Training loss: 0.17, Validation loss: 0.19
# Training acc: 94.91%, Validation acc: 94.19%
# Epoch 70:
# Training loss: 0.17, Validation loss: 0.18
# Training acc: 95.05%, Validation acc: 94.47%
# Epoch 71:
# Training loss: 0.16, Validation loss: 0.18
# Training acc: 95.16%, Validation acc: 94.49%
# Epoch 72:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.19%, Validation acc: 94.66%
# Epoch 73:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.24%, Validation acc: 94.56%
# Epoch 74:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.25%, Validation acc: 94.42%
# Epoch 75:
# Training loss: 0.16, Validation loss: 0.17
# Training acc: 95.23%, Validation acc: 94.70%

# %% [markdown]
# # Plot History of Training and Validation Loss

# %%
if LOADING:
    data = torch.load('best_weights.pt')
    train_loss_list = data['train_losses']
    valid_loss_list = data['valid_losses']
    train_acc_list = data['train_losses']
    valid_acc_list = data['valid_losses']   
    
fig, axs = plt.subplots(1, 2, figsize = (20, 5))

axs[0].plot(train_loss_list)
axs[0].plot(valid_loss_list)
axs[0].legend(['training loss', 'validation loss'])

axs[1].plot([i.item() for i in train_acc_list])
axs[1].plot([i.item() for i in valid_acc_list])
axs[1].legend(['training accuracy', 'validation accuracy'])

for ax in axs.flat:
    ax.set(xlabel='Number of Epochs', ylabel='Loss')

# %% [markdown]
# # Have a look on the Testing Result

# %%
data_iter = iter(validloader)
data = torch.load('best_weights.pt')
model.load_state_dict(data)
model.eval()
# Out:
# UNet(
#   (upfeature): FeatureMap(
#     (conv): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (contract1): DownConvBlock(
#     (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract2): DownConvBlock(
#     (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract3): DownConvBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (contract4): DownConvBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (max_pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (expand1): UpConvBlock(
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand2): UpConvBlock(
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand3): UpConvBlock(
#     (conv1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (expand4): UpConvBlock(
#     (conv1): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (activation): ReLU()
#     (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (downfeature): FeatureMap(
#     (conv): Conv2d(16, 23, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
images, masks = next(data_iter)
preds = torch.argmax(model(images.to(DEVICE)), dim = 1, keepdim = True)
for i, image in enumerate(images):
    fig, ax = plt.subplots(1, 3, figsize = (20, 20))
    ax[0].imshow(image.permute(1,2,0))
    ax[1].imshow(masks[i])
    ax[2].imshow(preds[i][0].detach().cpu().numpy())
    
    ax[0].set_title('Original Image')
    ax[1].set_title('Ground Truth')
    ax[2].set_title('Prediction')
